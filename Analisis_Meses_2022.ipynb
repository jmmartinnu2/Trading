# %% [markdown]
# <a href="https://colab.research.google.com/github/jmmartinnu2/Trading/blob/main/Analisis_Meses_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.DataFrame()

#creamos las columnas
df['Mes'] = None
df['VAH'] = None
df['Vpoc'] = None
df['VAL'] = None
df['Vol'] = None
df['Cierre'] = None
df['Vwap'] = None
df['Open'] = None
df['High'] = None
df['Low'] = None
df['Vol_VAH'] = None
df['Vol_VPOC'] = None
df['Vol_VAL'] = None
df['Poc_Naked'] = False
df['Rango_AreaValor'] = None
df['Vix-cierre'] = None


#añadimos filas por su nombre de fila
df.loc[0] = ['Enero',4733.75,4690,4368,40464300,4504.25,4529.95,4771,4803.50,4208,11200,187800,52100,True,365.75,24.83]
df.loc[1] = ['Febrero',4576.75,4498,4359,34995400,4368,4407.1,4493.25,4581.25,4097,40700,262100,96300,False,217.75,30.15]
df.loc[2] = ['Marzo',4457.75,4299,4146,31616100,4530.75,4373.95,4367.50,4633.50,4132,77200,130400,9800,False,311.75,20.56]
df.loc[3] = ['Abril',4589,4463.25,4290.25,31177700,4127.50,4378.17,4541,4591.25,4121.25,4800,206500,47600,True,298.75,33.40]
df.loc[4] = ['Mayo',4112.75,4017,3877,40873300,4135.25,4029.75,4126.50,4305.50,3810,10500,228300,41100,False,235.75,26.19]
df.loc[5] = ['Junio',3919.75,3774,3643,34544800,3781,3884.03,4143.75,4191.50,3639,80200,264100,600,False,276.75,28.71]
df.loc[6] = ['Julio',3987.50,3856.75,3800.75,32906500,4133.50,3902.45,3782,4144,3723.75,69700,270800,54600,True,186.75,21.33]
df.loc[7] = ['Agosto',4273,4140.25,4089.25,37053600,3956.50,4150.19,4137.50,4327.50,3953,45700,103000,8000,True,184,25.87]
#df.loc[8] = ['Septiembre',None,None,None,None,None, None, None, None, None,None,None,None,None,None]
#df.loc[9] = ['Octubre',None,None,None,None,None, None, None, None, None,None,None,None,None,None]

#Imprimo mi tabla con resultados
df
# Out:
#        Mes      VAH     Vpoc      VAL       Vol   Cierre     Vwap     Open  \
# 0    Enero  4733.75     4690     4368  40464300  4504.25  4529.95     4771
# 1  Febrero  4576.75     4498     4359  34995400  4368.00  4407.10  4493.25
# 2    Marzo  4457.75     4299     4146  31616100  4530.75  4373.95   4367.5
# 3    Abril  4589.00  4463.25  4290.25  31177700  4127.50  4378.17     4541
# 4     Mayo  4112.75     4017     3877  40873300  4135.25  4029.75   4126.5
# 5    Junio  3919.75     3774     3643  34544800  3781.00  3884.03  4143.75
# 6    Julio  3987.50  3856.75  3800.75  32906500  4133.50  3902.45     3782
# 7   Agosto  4273.00  4140.25  4089.25  37053600  3956.50  4150.19   4137.5
#
#       High      Low Vol_VAH Vol_VPOC Vol_VAL  Poc_Naked  Rango_AreaValor  \
# 0  4803.50     4208   11200   187800   52100       True           365.75
# 1  4581.25     4097   40700   262100   96300      False           217.75
# ...

# %%
df.describe()
# Out:
#                VAH       Cierre        Vwap        High  Rango_AreaValor  \
# count     8.000000     8.000000     8.00000     8.00000         8.000000
# mean   4331.281250  4192.093750  4206.94875  4447.25000       259.656250
# std     303.160832   261.427911   248.77225   236.67243        64.539016
# min    3919.750000  3781.000000  3884.03000  4144.00000       184.000000
# 25%    4081.437500  4084.750000  3997.92500  4277.00000       210.000000
# 50%    4365.375000  4134.375000  4262.07000  4454.37500       256.250000
# 75%    4579.812500  4402.062500  4385.40250  4601.81250       302.000000
# max    4733.750000  4530.750000  4529.95000  4803.50000       365.750000
#
#        Vix-cierre
# count    8.000000
# mean    26.380000
# std      4.325932
# min     20.560000
# 25%     23.955000
# 50%     26.030000
# 75%     29.070000
# max     33.400000

# %%
#Graficos de lineas
plt.plot(df['Mes'], df['Vwap'])
plt.show()

# %%
#Graficos de lineas
plt.scatter(df['Mes'], df['Vwap'])
plt.show()
